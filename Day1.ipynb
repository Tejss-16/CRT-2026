# %%
arr = eval(input())
print(max(arr))
# Out:
# [2,4,5,6,7,44]
# 44

# %%
n1 =int(input("n1: "))
n2 = int(input("n2: "))
n3 = int(input("n3: "))
print(max(n1,n2,n3))
# Out:
# n1: 12
# n2: 3
# n3: 4
# 12

# %%
n1 =int(input("n1: "))
n2 = int(input("n2: "))
n3 = int(input("n3: "))
if n1>n2:
    if n1>n3:
        print(n1)
    else:
        print(n3)
else:
    if n2>n3:
        print(n2)
    else:
        print(n3)
# Out:
# n1: 4
# n2: 66
# n3: 77
# 77

# %%
unit = int(input(""))
if unit<=100:
  bill = 0*unit
elif unit in range (101,200):
  bill = (unit-100)*5
elif unit in range (201,300):
  bill = (100*5)+(unit-200)*7
elif unit>300: bill = (100*5)+(100*7)+(unit-300)*10

print(bill)
# Out:
# 1455
# 12750

# %%
package=float(input("enter: "))
if package<=400000:
  tax = 0
  hand= package-(tax*package)
elif package>400000 and package<=800000:
  tax= 0.05
  hand = package-(package-400000)*tax
elif package>800000 and package<=1200000 :
  tax= 0.10
  hand= package-(package-800000)*tax-(800000-400000)*0.05
elif package>1200000 and package<=1500000:
  tax= 0.15
  hand= package-(package-1200000)*tax-(1200000-800000)*0.10-(800000-400000)*0.05
else:
  tax = 0.30
  hand= package-(package-1500000)*tax-(1500000-1200000)*0.15-(1200000-800000)*0.10-(800000-400000)*0.05

m= hand/12
print(f"in hand salary is {hand}")
print(f"monthly salary is {m}")
# Out:
# enter: 560000
# in hand salary is 552000.0
# monthly salary is 46000.0

# %%
price = float(input("enter: "))
if price <=1000:
  dis = 0
elif price>1000 and price<=1500:
  dis= 0.05
elif price>1500 and price<=3000:
  dis= 0.10
total= price-(price*dis)
print(f"final price {total}")
# Out:
# enter: 2345
# final price 2110.5

# %%
n =int(input("enter: "))
if n==1:
  print("monday")
elif n==2:
  print("tuesday")
elif n==3:
  print("wedday")
elif n==4:
  print("thruday")
elif n==5:
  print("friday")
elif n==6:
  print("satday")
elif n==7:
  print("sun")
else:
  print("invalid choise")
# Out:
# enter: 4
# thruday

# %%
n1=int(input("n1: "))
n2=int(input("n2: "))
i=input("enter arithmatic")
if i=="+":
  print(n1+n2)
elif i=="-":
  print(n1-n2)
elif i=="*":
  print(n1*n2)
elif i=="/":
  print(n1/n2)
else:
  print("pls enter valic arithmatic function")
# Out:
# n1: 4
# n2: 55
# enter arithmatic/
# 0.07272727272727272
